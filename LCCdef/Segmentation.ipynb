# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from matplotlib.pyplot import imshow

filename='C:/xampp/htdocs/up/upload/m0.png'
txt='C:/xampp/htdocs/up/upload/r.txt'
trhim='C:/xampp/htdocs/up/upload/trh.png'

import os
f.close()
if os.path.exists(txt):
    os.remove(txt)
else:
    print("No file")
    
if os.path.exists(trhim):
    os.remove(trhim)
else:
    print("No file")


img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
points = np.argwhere(thresh==0)
points=np.fliplr(points)
x,y,w,h =cv2.boundingRect(points)
x,y,w,h =x-10 , y -10 , w+20 , h +20
crop = gray [y:y+h , x:x+w]
ret ,thresh_crp =cv2.threshold(crop,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

imshow(thresh_crp)

# %%
rgb = cv2.cvtColor(crop,cv2.COLOR_GRAY2RGB)
imshow(rgb)

# %%
imshow(gray)

# %%
imshow(thresh)

# %%
cv2.imwrite('C:/xampp/htdocs/up/upload/trh.png',thresh)
# Out:
# True

# %%
f = open('C:/xampp/htdocs/up/upload/r.txt','w+')
a = 2
f.write('Valuue :'+str(a))
f.close()
